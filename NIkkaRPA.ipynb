# %%
import pyautogui as pg
import time
import AshTaleNikka as atn

import importlib
importlib.reload(atn)

# %%
"""
それぞれのボタンのクリック位置です。
基本的には下のセルで係数をうまい具合に設定すれば大丈夫だとは思いますが、
微調整したい場合はいじってください。

"""

def zahyou(係数, 左上):
    
    日課一覧 = {}

    # タスクバー（毎回位置がずれるから注意）
    # タスクバー = [1132, 1053] 
    日課一覧["タスクバー"] = [1094, 1057]

    日課一覧["終了"] = [1220*係数[0]+左上[0], (65-27)*係数[1]+左上[1]]
    日課一覧["王国"] = [1083*係数[0]+左上[0], (69-27)*係数[1]+左上[1]]


    日課一覧["武装の秘境"] = [852+左上[0], (305-27)*係数[1]+左上[1]]
    日課一覧["進む"] = [707*係数[0]+左上[0], (667-27)*係数[1]+左上[1]]
    日課一覧["武装_EX"] = [832*係数[0]+左上[0], (396-27)*係数[1]+左上[1]]
    日課一覧["武装_挑戦"] = [992*係数[0]+左上[0], (654-27)*係数[1]+左上[1]]
    日課一覧["即時入場"] = [909*係数[0]+左上[0], (600-27)*係数[1]+左上[1]]

    日課一覧["緋の章"] = [358*係数[0]+左上[0], (621-27)*係数[1]+左上[1]]
    日課一覧["焔の章"] = [351*係数[0]+左上[0], (506-27)*係数[1]+左上[1]]
    日課一覧["桜の章"] = [317*係数[0]+左上[0], (381-27)*係数[1]+左上[1]]
    日課一覧["龍の章"] = [372*係数[0]+左上[0], (263-27)*係数[1]+左上[1]]
    日課一覧["砂の章"] = [316*係数[0]+左上[0], (169-27)*係数[1]+左上[1]]


    日課一覧["護衛"] = [302*係数[0]+左上[0], (484-27)*係数[1]+左上[1]]
    日課一覧["護衛_受注"] = [923*係数[0]+左上[0], (645-27)*係数[1]+左上[1]]

    日課一覧["ドラゴンの秘宝"] = [1050*係数[0]+左上[0], (383-27)*係数[1]+左上[1]]
    日課一覧["ドラゴン_挑戦"] = [826*係数[0]+左上[0], (623-27)*係数[1]+左上[1]]

    日課一覧["絆魂の秘境"] = [769*係数[0]+左上[0], (461-27)*係数[1]+左上[1]]
    日課一覧["絆魂_挑戦"] = [680*係数[0]+左上[0], (663-27)*係数[1]+左上[1]]

    日課一覧["絆魂_ハード"] = [94*係数[0]+左上[0], (81-27)*係数[1]+左上[1]]
    日課一覧["絆魂_デイリー"] = [70*係数[0]+左上[0], (666-27)*係数[1]+左上[1]]

    日課一覧["競技場"] = [529*係数[0]+左上[0], (318-27)*係数[1]+左上[1]]
    日課一覧["天啓の試練"] = [1258*係数[0]+左上[0], (490-27)*係数[1]+左上[1]]


    日課一覧["ギルド"] = [1245*係数[0]+左上[0], (671-27)*係数[1]+左上[1]]
    日課一覧["イベント"] = [1160*係数[0]+左上[0], (566-27)*係数[1]+左上[1]]
    日課一覧["修練"] = [993*係数[0]+左上[0], (211-27)*係数[1]+左上[1]]
    日課一覧["寄付"] = [329*係数[0]+左上[0], (656-27)*係数[1]+左上[1]]

    日課一覧["デイリー"] = [1074*係数[0]+左上[0], (150-27)*係数[1]+左上[1]]
    日課一覧["デイリー１"] = [336*係数[0]+左上[0], (603-27)*係数[1]+左上[1]]
    日課一覧["デイリー２"] = [521*係数[0]+左上[0], (603-27)*係数[1]+左上[1]]
    日課一覧["デイリー３"] = [697*係数[0]+左上[0], (603-27)*係数[1]+左上[1]]
    日課一覧["デイリー４"] = [874*係数[0]+左上[0], (603-27)*係数[1]+左上[1]]
    日課一覧["デイリー５"] = [1051*係数[0]+左上[0], (603-27)*係数[1]+左上[1]]

    日課一覧["カバン"] = [1163*係数[0]+左上[0], (233-27)*係数[1]+左上[1]]
    日課一覧["階級"] = [1165*係数[0]+左上[0], (462-27)*係数[1]+左上[1]]    
    日課一覧["受け取り"] = [1019*係数[0]+左上[0], (559-27)*係数[1]+左上[1]]      
    
    
    日課一覧["お得セット"] = [998*係数[0]+左上[0], (70-27)*係数[1]+左上[1]]    
    日課一覧["ログイン"] = [159*係数[0]+左上[0], (650-27)*係数[1]+左上[1]]     
    日課一覧["ログイン受け取り"] = [966*係数[0]+左上[0], (649-27)*係数[1]+左上[1]]     

    
    日課一覧["聖杯クエスト"] = [328*係数[0]+左上[0], (281-27)*係数[1]+左上[1]]     
    日課一覧["聖杯クエスト受け取り"] = [335*係数[0]+左上[0], (333-27)*係数[1]+左上[1]]   
    日課一覧["聖杯_終了"] = [1026*係数[0]+左上[0], (96-27)*係数[1]+左上[1]]     
    # ソウルコロシアム = [358+左上[0], 621+左上[1]]
    
    日課一覧["ショップ"] = [910*係数[0]+左上[0], (71-27)*係数[1]+左上[1]]     
    日課一覧["金貨"] = [746*係数[0]+左上[0], (161-27)*係数[1]+左上[1]]       
    日課一覧["金貨交換"] = [289*係数[0]+左上[0], (671-27)*係数[1]+左上[1]]
    日課一覧["ポイント"] = [867*係数[0]+左上[0], (161-27)*係数[1]+左上[1]] 
    日課一覧["ショップ中心"] = [449*係数[0]+左上[0], (422-27)*係数[1]+左上[1]]
                      
    日課一覧["金貨１"] = [617*係数[0]+左上[0], (268-27)*係数[1]+左上[1]]                      
    日課一覧["金貨２"] = [329*係数[0]+左上[0], (394-27)*係数[1]+左上[1]]                      
    
    日課一覧["ポイント１"] = [325*係数[0]+左上[0], (264-27)*係数[1]+左上[1]]                     
    日課一覧["ポイント２"] = [315*係数[0]+左上[0], (389-27)*係数[1]+左上[1]]                    
    日課一覧["ポイント３"] = [612*係数[0]+左上[0], (520-27)*係数[1]+左上[1]]                     
    日課一覧["ポイント４"] = [320*係数[0]+左上[0], (316-27)*係数[1]+左上[1]]                   
    日課一覧["ポイント５"] = [627*係数[0]+左上[0], (317-27)*係数[1]+左上[1]]                     
    日課一覧["ポイント６"] = [327*係数[0]+左上[0], (435-27)*係数[1]+左上[1]]                    
    日課一覧["ポイント７"] = [315*係数[0]+左上[0], (563-27)*係数[1]+左上[1]]                    
                   
    日課一覧["個数"] = [935*係数[0]+左上[0], (579-27)*係数[1]+左上[1]]         
    日課一覧["９"] = [775*係数[0]+左上[0], (461-27)*係数[1]+左上[1]] 
    日課一覧["確認"] = [745*係数[0]+左上[0], (530-27)*係数[1]+左上[1]]                   
    日課一覧["購入"] = [938*係数[0]+左上[0], (661-27)*係数[1]+左上[1]]                     
                  
    日課一覧["タンス"] = [867*係数[0]+左上[0], (161-27)*係数[1]+左上[1]]     
    
    return 日課一覧

# %%
"""
私のPC版アシュテ（メインキャラ用）の縦と横を1とした比率を入れます。
（PC版でウィンドウ表示している場合は1で大丈夫……？）
print(pg.position()) 等を使って上記の座標と比較して、
使用者のアシュテ画面に合うように係数を設定してください。
"""

係数一覧 = {}
係数一覧["メイン"] = [1, 1]
係数一覧["サブ"] = [815/1245, (465-43)/(671-27)]


"""
アシュテのウィンドウのタイトルバーを除いた一番左上の部分の座標を入力します。
ウィンドウの場所を良く変える場合はそれぞれのパターンを追加すると使いやすいと思います。
"""

左上一覧 = {}
# アシュテのウィンドウの一番上の座標
左上一覧["メインデフォルト"] = [320, 193]
左上一覧["メイン左上寄せ"] = [0, 27]
左上一覧["メイン左寄せ"] = [0, 196]
左上一覧["サブ１"] = [0, 43]
左上一覧["サブ２"] = [908, 43]
左上一覧["サブ３"] = [0, 558]
左上一覧["サブ４"] = [908, 558]

メイン = zahyou(係数一覧["メイン"], 左上一覧["メイン左寄せ"])
サブ１ = zahyou(係数一覧["サブ"], 左上一覧["サブ１"])
サブ２ = zahyou(係数一覧["サブ"], 左上一覧["サブ２"])
サブ３ = zahyou(係数一覧["サブ"], 左上一覧["サブ３"])
サブ４ = zahyou(係数一覧["サブ"], 左上一覧["サブ４"])


"""
AshTaleNikka.pyを呼び出します。
私はメインをアクティブにするとサブを隠してしまうため、
メインでまず作業をしてその後にメインを最小化してサブ達の日課を消化するために下記のように分けています。

"""

日課巡回 = atn.nikka(メイン)
日課巡回サブ = [atn.nikka(サブ１), atn.nikka(サブ２), atn.nikka(サブ３), atn.nikka(サブ４)]

# %%
"""
護衛、ドラゴンの秘宝、絆魂の秘境、武装の秘境の自動周回です。
実行時に、ブラウザがアシュテのウィンドウと被らないように注意してください。
また、デュアルディスプレイでアシュテとブラウザを別々のディスプレイにした場合に上手く動作しないことを確認しています。
"""

日課巡回.goei()
日課巡回.dragon()
日課巡回.hankon()
日課巡回.busou_loop()

# %%
"""
メイン用
デイリー報酬、絆ハード報酬、階級報酬、ショップ金貨、ログイン報酬、聖杯クエスト、ギルド修練の自動化です。
ギルド修練はランクアップしたときの挙動を考慮できていないので一番最後にした方がいいです。
"""

# メルブに戻ること
# スキル表示ではない方の画面（スティグマとかギルドとかを選択できる画面）にすること
# 荷物を少し減らすこと（報酬を受け取れない可能性があるため）

日課巡回.daily()
日課巡回.hankon_daily()
日課巡回.bag_daily()
日課巡回.shop_daily()
日課巡回.login_daily()
日課巡回.seihai_daily()
日課巡回.syuren()

# %%
"""
サブ用
デイリー報酬、絆ハード報酬、階級報酬、ショップ金貨、ログイン報酬、聖杯クエスト、ギルド修練の自動化です。
ギルド修練はランクアップしたときの挙動を考慮できていないので一番最後にした方がいいです。
"""

# メルブに戻ること
# スキル表示ではない方の画面（スティグマとかギルドとかを選択できる画面）にすること
# 荷物を少し減らすこと（報酬を受け取れない可能性があるため）

for サブず in 日課巡回サブ:
    サブず.daily()
    サブず.hankon_daily()
    サブず.bag_daily()
    サブず.shop_daily()
    サブず.login_daily()
    サブず.seihai_daily()
    サブず.syuren()

# %%
"""
未実装のもの
～日課～
・競技場
・ガチャ
・30日パスポート
・タンス

・天空の城
・太古の遺跡

・周年イベ（ログボ、バルーン）


～週課～
・ソウルコロシアム

～注意～
周年イベントが終わるとボタンの位置が変わるので座標を書き換える必要があります。


"""
